# %% [markdown]
# # *IMPORTING LIBRARIES*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import iplot
from plotly.subplots import make_subplots

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # *READING DATASET*

# %% [markdown]
# # HUMAN SOCIALISING DATASET
#
# # Overview -
#
# The "Time-Wasters on Social Media" dataset offers a detailed look into user behavior and engagement with social media platforms.
# It captures various attributes that can help analyze the impact of social media on users' time and productivity.
# This dataset is valuable for researchers, marketers, and social scientists aiming to understand the nuances of social media consumption.
#
# # Objective -
#
# How does social media usage affect productivity, and who are the biggest time wasters?

# %%
ds_socialtime=pd.read_csv(r"C:\Users\hp\Downloads\Time-Wasters on Social Media.csv")
ds_socialtime
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Barzil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# ..      ...  ...     ...            ...     ...    ...            ...
# 995     996   22    Male          India   74254   True           True
# 996     997   40  Female       Pakistan   27006  False          False
# 997     998   27    Male          India   94218   True           True
# 998     999   61    Male       Pakistan   85344   True          False
# 999    1000   19    Male          India   53840   True           True
#
#         Profession Demographics   Platform  ...  ProductivityLoss  \
# 0         Engineer        Rural  Instagram  ...                 3
# 1           Artist        Urban  Instagram  ...                 5
# 2         Engineer        Rural   Facebook  ...                 6
# 3    Waiting staff        Rural    YouTube  ...                 3
# 4          Manager        Urban     TikTok  ...                 8
# ..             ...          ...        ...  ...               ...
# 995       Students        Rural     TikTok  ...                 9
# 996  Waiting staff        Urban   Facebook  ...                 8
# 997  Waiting staff        Rural     TikTok  ...                 9
# 998       Students        Urban    YouTube  ...                 3
# 999         driver        Urban    YouTube  ...                 6
#
#      Satisfaction     Watch Reason  DeviceType       OS  Watch Time  \
# 0               7  Procrastination  Smartphone  Android     9:00 PM
# 1               5            Habit    Computer  Android     5:00 PM
# 2               4    Entertainment      Tablet  Android     2:00 PM
# 3               7            Habit  Smartphone  Android     9:00 PM
# 4               2          Boredom  Smartphone      iOS     8:00 AM
# ..            ...              ...         ...      ...         ...
# 995             1  Procrastination  Smartphone      iOS     5:45 PM
# 996             2          Boredom  Smartphone    MacOS    10:15 PM
# 997             1  Procrastination  Smartphone      iOS    10:15 PM
# 998             7  Procrastination  Smartphone    MacOS    10:15 PM
# 999             4  Procrastination  Smartphone  Android     4:25 PM
#
#      Self Control  Addiction Level  CurrentActivity  ConnectionType
# 0               5                5        Commuting     Mobile Data
# 1               7                3        At school           Wi-Fi
# 2               8                2          At home     Mobile Data
# 3               5                5        Commuting     Mobile Data
# 4              10                0          At home     Mobile Data
# ..            ...              ...              ...             ...
# 995            10                0          At work     Mobile Data
# 996            10                0          At home     Mobile Data
# 997            10                0        Commuting     Mobile Data
# 998             5                5          At work           Wi-Fi
# 999             8                2          At home     Mobile Data
#
# [1000 rows x 31 columns]

# %% [markdown]
# # Columns Description
#
# UserID: Unique identifier assigned to each user.
#
# Age: The user's age.
#
# Gender: The user's gender (e.g., male, female, non-binary).
#
# Location: Geographic location of the user.
#
# Income: The user's income level.
#
# Debt: Amount of debt the user has.
#
# Owns Property: Indicates whether the user owns property.
#
# Profession: The user's occupation or job.
#
# Demographics: Statistical data about the user (e.g., age, gender, income).
#
# Platform: The platform the user is using (e.g., website, mobile app).
#
# Total Time Spent: The total time the user spends on the platform.
#
# Number of Sessions: The number of times the user has logged into the platform.
#
# Video ID: Unique identifier for a video.
#
# Video Category: The category or genre of the video.
#
# Video Length: Duration of the video.
#
# Engagement: User interaction with the video (e.g., likes, comments, shares).
#
# Importance Score: A score indicating how important the video is to the user.
#
# Time Spent On Video: The amount of time the user spends watching a video.
#
# Number of Videos Watched: The total number of videos watched by the user.
#
# Scroll Rate: The rate at which the user scrolls through content.
#
# Frequency: How often the user engages with the platform.
#
# Productivity Loss: The impact of platform usage on the user's productivity.
#
# Satisfaction: The user's satisfaction level with the platform or content.
#
# Watch Reason: The reason why the user is watching a video (e.g., entertainment, education).
#
# Device Type: The type of device the user is using (e.g., smartphone, tablet, desktop).
#
# OS: The operating system of the user's device (e.g., iOS, Android, Windows).
#
# Watch Time: The time of day when the user watches videos.
#
# Self Control: The user's ability to control their usage of the platform.
#
# Addiction Level: The user's level of dependency on the platform.
#
# Current Activity: What the user is doing while watching the video.
#
# Connection Type: The type of internet connection the user has (e.g., Wi-Fi, cellular)

# %%
ds_socialtime.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
ds_socialtime.columns
# Out:
# Index(['UserID', 'Age', 'Gender', 'Location', 'Income', 'Debt',
#        'Owns Property', 'Profession', 'Demographics', 'Platform',
#        'Total Time Spent', 'Number of Sessions', 'Video ID', 'Video Category',
#        'Video Length', 'Engagement', 'Importance Score', 'Time Spent On Video',
#        'Number of Videos Watched', 'Scroll Rate', 'Frequency',
#        'ProductivityLoss', 'Satisfaction', 'Watch Reason', 'DeviceType', 'OS',
#        'Watch Time', 'Self Control', 'Addiction Level', 'CurrentActivity',
#        'ConnectionType'],
#       dtype='object')

# %%
#TO GET THE NUMERICAL COLUMNS

ds_socialtime.describe().columns
# Out:
# Index(['UserID', 'Age', 'Income', 'Total Time Spent', 'Number of Sessions',
#        'Video ID', 'Video Length', 'Engagement', 'Importance Score',
#        'Time Spent On Video', 'Number of Videos Watched', 'Scroll Rate',
#        'ProductivityLoss', 'Satisfaction', 'Self Control', 'Addiction Level'],
#       dtype='object')

# %%
#TO GET THE CATEGORICAL COLUMNS

y=list(set(ds_socialtime.columns)-set(ds_socialtime.describe().columns))
y
# Out:
# ['Watch Time',
#  'Video Category',
#  'Watch Reason',
#  'Gender',
#  'Profession',
#  'Owns Property',
#  'CurrentActivity',
#  'Platform',
#  'Demographics',
#  'Location',
#  'Debt',
#  'Frequency',
#  'DeviceType',
#  'ConnectionType',
#  'OS']

# %%
#DECSRIBING LIST OF COLUMNS

ds_socialtime.columns.to_list()
# Out:
# ['UserID',
#  'Age',
#  'Gender',
#  'Location',
#  'Income',
#  'Debt',
#  'Owns Property',
#  'Profession',
#  'Demographics',
#  'Platform',
#  'Total Time Spent',
#  'Number of Sessions',
#  'Video ID',
#  'Video Category',
#  'Video Length',
#  'Engagement',
#  'Importance Score',
#  'Time Spent On Video',
#  'Number of Videos Watched',
#  'Scroll Rate',
#  'Frequency',
#  'ProductivityLoss',
#  'Satisfaction',
#  'Watch Reason',
#  'DeviceType',
#  'OS',
#  'Watch Time',
#  'Self Control',
#  'Addiction Level',
#  'CurrentActivity',
#  'ConnectionType']

# %%
#top 5

ds_socialtime.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  ...  ProductivityLoss  Satisfaction  \
# 0       Engineer        Rural  Instagram  ...                 3             7
# 1         Artist        Urban  Instagram  ...                 5             5
# 2       Engineer        Rural   Facebook  ...                 6             4
# 3  Waiting staff        Rural    YouTube  ...                 3             7
# 4        Manager        Urban     TikTok  ...                 8             2
#
#       Watch Reason  DeviceType       OS  Watch Time  Self Control  \
# 0  Procrastination  Smartphone  Android     9:00 PM             5
# 1            Habit    Computer  Android     5:00 PM             7
# 2    Entertainment      Tablet  Android     2:00 PM             8
# 3            Habit  Smartphone  Android     9:00 PM             5
# 4          Boredom  Smartphone      iOS     8:00 AM            10
#
#    Addiction Level  CurrentActivity  ConnectionType
# 0                5        Commuting     Mobile Data
# 1                3        At school           Wi-Fi
# 2                2          At home     Mobile Data
# 3                5        Commuting     Mobile Data
# 4                0          At home     Mobile Data
#
# [5 rows x 31 columns]

# %%
#bottom 5

ds_socialtime.tail()
# Out:
#      UserID  Age  Gender  Location  Income   Debt  Owns Property  \
# 995     996   22    Male     India   74254   True           True
# 996     997   40  Female  Pakistan   27006  False          False
# 997     998   27    Male     India   94218   True           True
# 998     999   61    Male  Pakistan   85344   True          False
# 999    1000   19    Male     India   53840   True           True
#
#         Profession Demographics  Platform  ...  ProductivityLoss  \
# 995       Students        Rural    TikTok  ...                 9
# 996  Waiting staff        Urban  Facebook  ...                 8
# 997  Waiting staff        Rural    TikTok  ...                 9
# 998       Students        Urban   YouTube  ...                 3
# 999         driver        Urban   YouTube  ...                 6
#
#      Satisfaction     Watch Reason  DeviceType       OS  Watch Time  \
# 995             1  Procrastination  Smartphone      iOS     5:45 PM
# 996             2          Boredom  Smartphone    MacOS    10:15 PM
# 997             1  Procrastination  Smartphone      iOS    10:15 PM
# 998             7  Procrastination  Smartphone    MacOS    10:15 PM
# 999             4  Procrastination  Smartphone  Android     4:25 PM
#
#      Self Control  Addiction Level  CurrentActivity  ConnectionType
# 995            10                0          At work     Mobile Data
# 996            10                0          At home     Mobile Data
# 997            10                0        Commuting     Mobile Data
# 998             5                5          At work           Wi-Fi
# 999             8                2          At home     Mobile Data
#
# [5 rows x 31 columns]

# %%
ds_socialtime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   UserID                    1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Location                  1000 non-null   object
#  4   Income                    1000 non-null   int64
#  5   Debt                      1000 non-null   bool
#  6   Owns Property             1000 non-null   bool
#  7   Profession                1000 non-null   object
#  8   Demographics              1000 non-null   object
#  9   Platform                  1000 non-null   object
#  10  Total Time Spent          1000 non-null   int64
#  11  Number of Sessions        1000 non-null   int64
#  12  Video ID                  1000 non-null   int64
#  13  Video Category            1000 non-null   object
#  14  Video Length              1000 non-null   int64
#  15  Engagement                1000 non-null   int64
#  16  Importance Score          1000 non-null   int64
#  17  Time Spent On Video       1000 non-null   int64
#  18  Number of Videos Watched  1000 non-null   int64
#  19  Scroll Rate               1000 non-null   int64
#  20  Frequency                 1000 non-null   object
#  21  ProductivityLoss          1000 non-null   int64
#  22  Satisfaction              1000 non-null   int64
#  23  Watch Reason              1000 non-null   object
#  24  DeviceType                1000 non-null   object
#  25  OS                        1000 non-null   object
#  26  Watch Time                1000 non-null   object
#  27  Self Control              1000 non-null   int64
#  28  Addiction Level           1000 non-null   int64
#  29  CurrentActivity           1000 non-null   object
#  30  ConnectionType            1000 non-null   object
# dtypes: bool(2), int64(16), object(13)
# memory usage: 228.6+ KB

# %%
ds_socialtime.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   UserID                    1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Location                  1000 non-null   object
#  4   Income                    1000 non-null   int64
#  5   Debt                      1000 non-null   bool
#  6   Owns Property             1000 non-null   bool
#  7   Profession                1000 non-null   object
#  8   Demographics              1000 non-null   object
#  9   Platform                  1000 non-null   object
#  10  Total Time Spent          1000 non-null   int64
#  11  Number of Sessions        1000 non-null   int64
#  12  Video ID                  1000 non-null   int64
#  13  Video Category            1000 non-null   object
#  14  Video Length              1000 non-null   int64
#  15  Engagement                1000 non-null   int64
#  16  Importance Score          1000 non-null   int64
#  17  Time Spent On Video       1000 non-null   int64
#  18  Number of Videos Watched  1000 non-null   int64
#  19  Scroll Rate               1000 non-null   int64
#  20  Frequency                 1000 non-null   object
#  21  ProductivityLoss          1000 non-null   int64
#  22  Satisfaction              1000 non-null   int64
#  23  Watch Reason              1000 non-null   object
#  24  DeviceType                1000 non-null   object
#  25  OS                        1000 non-null   object
#  26  Watch Time                1000 non-null   object
#  27  Self Control              1000 non-null   int64
#  28  Addiction Level           1000 non-null   int64
#  29  CurrentActivity           1000 non-null   object
#  30  ConnectionType            1000 non-null   object
# dtypes: bool(2), int64(16), object(13)
# memory usage: 228.6+ KB

# %%
ds_socialtime.describe()
# Out:
#             UserID          Age        Income  Total Time Spent  \
# count  1000.000000  1000.000000   1000.000000       1000.000000
# mean    500.500000    40.986000  59524.213000        151.406000
# std     288.819436    13.497852  23736.212925         83.952637
# min       1.000000    18.000000  20138.000000         10.000000
# 25%     250.750000    29.000000  38675.250000         78.000000
# 50%     500.500000    42.000000  58805.000000        152.000000
# 75%     750.250000    52.000000  79792.250000        223.000000
# max    1000.000000    64.000000  99676.000000        298.000000
#
#        Number of Sessions     Video ID  Video Length   Engagement  \
# count         1000.000000  1000.000000   1000.000000  1000.000000
# mean            10.013000  4891.738000     15.214000  4997.159000
# std              5.380314  2853.144258      8.224953  2910.053701
# min              1.000000    11.000000      1.000000    15.000000
# 25%              6.000000  2542.000000      8.000000  2415.750000
# 50%             10.000000  4720.500000     15.000000  5016.000000
# 75%             15.000000  7346.000000     22.000000  7540.250000
# max             19.000000  9997.000000     29.000000  9982.000000
#
#        Importance Score  Time Spent On Video  Number of Videos Watched  \
# count       1000.000000          1000.000000               1000.000000
# mean           5.129000            14.973000                 25.248000
# std            2.582834             8.200092                 14.029159
# min            1.000000             1.000000                  1.000000
# 25%            3.000000             8.000000                 14.000000
# 50%            5.000000            15.000000                 25.000000
# 75%            7.000000            22.000000                 37.000000
# max            9.000000            29.000000                 49.000000
#
#        Scroll Rate  ProductivityLoss  Satisfaction  Self Control  \
# count  1000.000000       1000.000000   1000.000000   1000.000000
# mean     49.774000          5.136000      4.864000      7.094000
# std      29.197798          2.122265      2.122265      2.058495
# min       1.000000          1.000000      1.000000      3.000000
# 25%      23.000000          3.000000      4.000000      5.000000
# 50%      50.000000          5.000000      5.000000      7.000000
# 75%      74.000000          6.000000      7.000000      8.000000
# max      99.000000          9.000000      9.000000     10.000000
#
#        Addiction Level
# count      1000.000000
# mean          2.906000
# std           2.058495
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           5.000000
# max           7.000000

# %%
#INSPECTING DATAFRAME STRUCTURE

def summary(ds_socialtime):
    print(f'data shape: {ds_socialtime.shape}')
    summ = pd.DataFrame(ds_socialtime.dtypes, columns=['Data Type'])
    summ['Missing#'] = ds_socialtime.isna().sum()
    summ['Missing%'] = (ds_socialtime.isna().sum())/len(ds_socialtime)
    summ['Dups'] = ds_socialtime.duplicated().sum()
    summ['Uniques'] = ds_socialtime.nunique().values
    summ['Count'] = ds_socialtime.count().values
    desc = pd.DataFrame(ds_socialtime.describe(include='all').transpose())
    summ['Min'] = desc['min'].values
    summ['Max'] = desc['max'].values
    summ['Average'] = desc['mean'].values
    summ['Standard Deviation'] = desc['std'].values
    summ['First Value'] = ds_socialtime.loc[0].values
    summ['Second Value'] = ds_socialtime.loc[1].values
    summ['Third Value'] = ds_socialtime.loc[2].values

    display(summ)
    
summary(ds_socialtime)
# Out:
# data shape: (1000, 31)
#                          Data Type  Missing#  Missing%  Dups  Uniques  Count  \
# UserID                       int64         0       0.0     0     1000   1000
# Age                          int64         0       0.0     0       47   1000
# Gender                      object         0       0.0     0        3   1000
# Location                    object         0       0.0     0       10   1000
# Income                       int64         0       0.0     0      996   1000
# Debt                          bool         0       0.0     0        2   1000
# Owns Property                 bool         0       0.0     0        2   1000
# Profession                  object         0       0.0     0        9   1000
# Demographics                object         0       0.0     0        2   1000
# Platform                    object         0       0.0     0        4   1000
# Total Time Spent             int64         0       0.0     0      278   1000
# Number of Sessions           int64         0       0.0     0       19   1000
# Video ID                     int64         0       0.0     0      947   1000
# Video Category              object         0       0.0     0        9   1000
# Video Length                 int64         0       0.0     0       29   1000
# Engagement                   int64         0       0.0     0      953   1000
# Importance Score             int64         0       0.0     0        9   1000
# Time Spent On Video          int64         0       0.0     0       29   1000
# Number of Videos Watched     int64         0       0.0     0       49   1000
# Scroll Rate                  int64         0       0.0     0       99   1000
# Frequency                   object         0       0.0     0        4   1000
# ProductivityLoss             int64         0       0.0     0        9   1000
# Satisfaction                 int64         0       0.0     0        9   1000
# Watch Reason                object         0       0.0     0        4   1000
# DeviceType                  object         0       0.0     0        3   1000
# OS                          object         0       0.0     0        4   1000
# Watch Time                  object         0       0.0     0       16   1000
# Self Control                 int64         0       0.0     0        8   1000
# Addiction Level              int64         0       0.0     0        8   1000
# CurrentActivity             object         0       0.0     0        4   1000
# ConnectionType              object         0       0.0     0        2   1000
#
#                               Min      Max    Average Standard Deviation  \
# UserID                        1.0   1000.0      500.5         288.819436
# Age                          18.0     64.0     40.986          13.497852
# Gender                        NaN      NaN        NaN                NaN
# Location                      NaN      NaN        NaN                NaN
# Income                    20138.0  99676.0  59524.213       23736.212925
# Debt                          NaN      NaN        NaN                NaN
# Owns Property                 NaN      NaN        NaN                NaN
# Profession                    NaN      NaN        NaN                NaN
# Demographics                  NaN      NaN        NaN                NaN
# Platform                      NaN      NaN        NaN                NaN
# Total Time Spent             10.0    298.0    151.406          83.952637
# Number of Sessions            1.0     19.0     10.013           5.380314
# Video ID                     11.0   9997.0   4891.738        2853.144258
# Video Category                NaN      NaN        NaN                NaN
# Video Length                  1.0     29.0     15.214           8.224953
# Engagement                   15.0   9982.0   4997.159        2910.053701
# Importance Score              1.0      9.0      5.129           2.582834
# Time Spent On Video           1.0     29.0     14.973           8.200092
# Number of Videos Watched      1.0     49.0     25.248          14.029159
# Scroll Rate                   1.0     99.0     49.774          29.197798
# Frequency                     NaN      NaN        NaN                NaN
# ProductivityLoss              1.0      9.0      5.136           2.122265
# Satisfaction                  1.0      9.0      4.864           2.122265
# Watch Reason                  NaN      NaN        NaN                NaN
# DeviceType                    NaN      NaN        NaN                NaN
# OS                            NaN      NaN        NaN                NaN
# Watch Time                    NaN      NaN        NaN                NaN
# Self Control                  3.0     10.0      7.094           2.058495
# Addiction Level               0.0      7.0      2.906           2.058495
# CurrentActivity               NaN      NaN        NaN                NaN
# ConnectionType                NaN      NaN        NaN                NaN
#
#                               First Value Second Value    Third Value
# UserID                                  1            2              3
# Age                                    56           46             32
# Gender                               Male       Female         Female
# Location                         Pakistan       Mexico  United States
# Income                              82812        27999          42436
# Debt                                 True        False          False
# Owns Property                        True         True           True
# Profession                       Engineer       Artist       Engineer
# Demographics                        Rural        Urban          Rural
# Platform                        Instagram    Instagram       Facebook
# Total Time Spent                       80          228             30
# Number of Sessions                     17           14              6
# Video ID                             4229         2131           4367
# Video Category                     Pranks       Pranks          Vlogs
# Video Length                           24           19             19
# Engagement                           7867         5944           8674
# Importance Score                        5            6              3
# Time Spent On Video                    26           25              9
# Number of Videos Watched               22           31              7
# Scroll Rate                            87           46             88
# Frequency                           Night    Afternoon        Evening
# ProductivityLoss                        3            5              6
# Satisfaction                            7            5              4
# Watch Reason              Procrastination        Habit  Entertainment
# DeviceType                     Smartphone     Computer         Tablet
# OS                                Android      Android        Android
# Watch Time                        9:00 PM      5:00 PM        2:00 PM
# Self Control                            5            7              8
# Addiction Level                         5            3              2
# CurrentActivity                 Commuting    At school        At home
# ConnectionType                Mobile Data        Wi-Fi    Mobile Data

# %%
def missing_values(dataframe):
    return round(ds_socialtime.isnull().sum()/len(ds_socialtime)*100,2).sort_values(ascending=False)

# %%
missing_values(ds_socialtime)
# Out:
# UserID                      0.0
# Importance Score            0.0
# CurrentActivity             0.0
# Addiction Level             0.0
# Self Control                0.0
# Watch Time                  0.0
# OS                          0.0
# DeviceType                  0.0
# Watch Reason                0.0
# Satisfaction                0.0
# ProductivityLoss            0.0
# Frequency                   0.0
# Scroll Rate                 0.0
# Number of Videos Watched    0.0
# Time Spent On Video         0.0
# Engagement                  0.0
# Age                         0.0
# Video Length                0.0
# Video Category              0.0
# Video ID                    0.0
# Number of Sessions          0.0
# Total Time Spent            0.0
# Platform                    0.0
# Demographics                0.0
# Profession                  0.0
# Owns Property               0.0
# Debt                        0.0
# Income                      0.0
# Location                    0.0
# Gender                      0.0
# ConnectionType              0.0
# dtype: float64

# %%
null=missing_values(ds_socialtime)[missing_values(ds_socialtime)>50]
null
# Out:
# Series([], dtype: float64)

# %%
null.index
# Out:
# Index([], dtype='object')

# %%
ds_socialtime.drop(columns=null.index,inplace=True)

# %%
ds_socialtime.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  ...  ProductivityLoss  Satisfaction  \
# 0       Engineer        Rural  Instagram  ...                 3             7
# 1         Artist        Urban  Instagram  ...                 5             5
# 2       Engineer        Rural   Facebook  ...                 6             4
# 3  Waiting staff        Rural    YouTube  ...                 3             7
# 4        Manager        Urban     TikTok  ...                 8             2
#
#       Watch Reason  DeviceType       OS  Watch Time  Self Control  \
# 0  Procrastination  Smartphone  Android     9:00 PM             5
# 1            Habit    Computer  Android     5:00 PM             7
# 2    Entertainment      Tablet  Android     2:00 PM             8
# 3            Habit  Smartphone  Android     9:00 PM             5
# 4          Boredom  Smartphone      iOS     8:00 AM            10
#
#    Addiction Level  CurrentActivity  ConnectionType
# 0                5        Commuting     Mobile Data
# 1                3        At school           Wi-Fi
# 2                2          At home     Mobile Data
# 3                5        Commuting     Mobile Data
# 4                0          At home     Mobile Data
#
# [5 rows x 31 columns]

# %%
null1=missing_values(ds_socialtime)[missing_values(ds_socialtime)>40]
null1
# Out:
# Series([], dtype: float64)

# %%
null1.index
# Out:
# Index([], dtype='object')

# %%
ds_socialtime.drop(columns=null1.index,inplace=True)

# %%
ds_socialtime.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  ...  ProductivityLoss  Satisfaction  \
# 0       Engineer        Rural  Instagram  ...                 3             7
# 1         Artist        Urban  Instagram  ...                 5             5
# 2       Engineer        Rural   Facebook  ...                 6             4
# 3  Waiting staff        Rural    YouTube  ...                 3             7
# 4        Manager        Urban     TikTok  ...                 8             2
#
#       Watch Reason  DeviceType       OS  Watch Time  Self Control  \
# 0  Procrastination  Smartphone  Android     9:00 PM             5
# 1            Habit    Computer  Android     5:00 PM             7
# 2    Entertainment      Tablet  Android     2:00 PM             8
# 3            Habit  Smartphone  Android     9:00 PM             5
# 4          Boredom  Smartphone      iOS     8:00 AM            10
#
#    Addiction Level  CurrentActivity  ConnectionType
# 0                5        Commuting     Mobile Data
# 1                3        At school           Wi-Fi
# 2                2          At home     Mobile Data
# 3                5        Commuting     Mobile Data
# 4                0          At home     Mobile Data
#
# [5 rows x 31 columns]

# %%
ds_socialtime["Gender"].value_counts()
# Out:
# Gender
# Male      514
# Female    322
# Other     164
# Name: count, dtype: int64

# %%
ds_socialtime["Gender"].value_counts(normalize=True)
# Out:
# Gender
# Male      0.514
# Female    0.322
# Other     0.164
# Name: proportion, dtype: float64

# %% [markdown]
# # *UNIVARIANT ANALYSIS*

# %% [markdown]
# # ANALYSING ADDICTION LEVEL

# %% [markdown]
# The Addiction Level from 0 to 7 in your dataset represents the intensity of social media usage,
# where higher numbers indicate greater engagement or dependency.
#
# *Level 0: No or very little use of social media.
#
# *Level 1: Very low use or dependence.
#
# *Level 2: Mild use, but not excessive.
#
# *Level 3: Moderate use, part of the daily routine.
#
# *Level 4: Significant use, affecting time management.
#
# *Level 5: High use, impacting other areas of life.
#
# *Level 6: Very high use, possibly neglecting responsibilities.
#
# *Level 7: Extreme use, with a strong negative impact.
#
# The higher the level, the more time or dependency on social media

# %%
ds_socialtime['Addiction Level'].unique()
# Out:
# array([5, 3, 2, 0, 1, 6, 7, 4], dtype=int64)

# %%
#Finding counts of each level

counts=ds_socialtime['Addiction Level'].value_counts().to_frame().reset_index()
counts
# Out:
#    Addiction Level  count
# 0                2    248
# 1                5    228
# 2                0    180
# 3                3    159
# 4                1     60
# 5                7     55
# 6                4     36
# 7                6     34

# %%
plt.figure(figsize=(10,6))
plt.pie(counts['count'],labels=counts['Addiction Level'],explode=(0.1,0,0,0,0,0,0,0),autopct="%1.2f%%")
plt.title('ADDICTION LEVEL OF SOCIAL MEDIA',color='red')

plt.show()

# %% [markdown]
# *Most Common Addiction Level : Addiction Level 2 is the most common, with 248 users. This suggests that a significant
#                               number of users are moderately addicted to the platform.
#
# *Low Addiction Level : Addiction level 6 has a lower count of 34 (3.40%) , indicating a less frequent addiction level in the dataset.
#
# *High Addiction Levels are Rare : Levels 5 to 7 have fewer users (55, 36, and 34, respectively),
#                                  showing that extremely high addiction levels are less prevalent

# %% [markdown]
# # ANALYSIS OF ADDICTION LEVELS ACROSS AGE CATEGORIES

# %%
# Categorizing Age into Young, Middle-Age, and Old Groups Based on Age Bins

age=pd.cut(ds_socialtime['Age'],bins=[ds_socialtime['Age'].min(),30,50,ds_socialtime['Age'].max()],labels=['young','middle_age','old'])
addiction_by_age_group = ds_socialtime.groupby(age)['Addiction Level'].mean().reset_index()
addiction_by_age_group
# Out:
#           Age  Addiction Level
# 0       young         2.745968
# 1  middle_age         3.002283
# 2         old         2.899654

# %%
plt.bar(addiction_by_age_group['Age'],addiction_by_age_group['Addiction Level'],color='skyblue')
plt.title('AVERAGE ADDICTION LEVEL BY AGE GROUP',color='blue')
plt.xlabel('AGE GROUP')
plt.ylabel('AVERAGE ADDICTION LEVEL')
plt.show()

# %% [markdown]
# <!-- The middle_age group has the highest average addiction level at 3.00, compared to the young group at 2.75 and the old group at 2.90. -->

# %% [markdown]
# The middle_age group has the highest average addiction level at 3.00, compared to the young group at 2.75 and the old group at 2.90.

# %% [markdown]
# # ANALYSIS OF ADDICTION LEVEL BY GENDER WISE

# %%
addiction_by_gender=ds_socialtime.groupby('Gender')['Addiction Level'].mean().reset_index()
addiction_by_gender
# Out:
#    Gender  Addiction Level
# 0  Female         2.906832
# 1    Male         2.964981
# 2   Other         2.719512

# %%
plt.bar(addiction_by_gender['Gender'],addiction_by_gender['Addiction Level'],color='black')
plt.title('AVERAGE ADDICTION LEVEL BY GENDER WISE',color='red')
plt.xlabel('GENDER')
plt.ylabel('AVERAGE ADDICTION LEVEL')
plt.show()

# %% [markdown]
# *Male Group Has the Highest Addiction Level:
# The Male group has the highest addiction level with a value of 2.965, indicating that males tend to have a higher addiction level compared to other genders.
#
# *The differences in addiction levels across genders are relatively small, with values ranging from 2.720 to 2.965.

# %% [markdown]
# # USAGE OF SOCIAL MEDIA BY PROFESSION (ANALYSIS OF PROFESSION DISTRIBUTION)

# %%
socialmedia_by_profession=ds_socialtime['Profession'].value_counts().reset_index()
socialmedia_by_profession
# Out:
#       Profession  count
# 0       Students    246
# 1  Waiting staff    194
# 2   Labor/Worker    186
# 3         driver    113
# 4       Engineer     65
# 5        Cashier     56
# 6        Manager     54
# 7         Artist     47
# 8        Teacher     39

# %%
plt.figure(figsize=(10,5))
plt.bar(socialmedia_by_profession['Profession'],socialmedia_by_profession['count'],color='g')
plt.title('USAGE OF SOCIAL MEDIA BY PROFESSION',color='red')
plt.xlabel('PROFESSION')
plt.ylabel('COUNT')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *The dataset is largely dominated by students and service industry roles (waiting staff, labor/workers).
#
# *while skilled professions such as engineers, managers, and teachers have smaller representations.
#
# *Creative professions (artists) are also present but in lower numbers.

# %% [markdown]
# # ANALYSIS OF TOTAL TIME SPEND ON SOCIAL MEDIA PLATFORMS

# %%
most_used_platform=ds_socialtime.groupby('Platform')['Total Time Spent'].sum().reset_index()
most_used_platform
# Out:
#     Platform  Total Time Spent
# 0   Facebook             34295
# 1  Instagram             37609
# 2     TikTok             41297
# 3    YouTube             38205

# %%
plt.pie(most_used_platform['Total Time Spent'],labels=most_used_platform['Platform'],explode=(0,0,0.1,0),autopct='%1.2f%%')
plt.title('TOTAL TIME SPENT ON SOCIAL MEDIA PLATFORMS',color='g')
plt.show()

# %% [markdown]
# *It looks like TikTok is the most popular platform, followed closely by YouTube and Instagram.
#
# *Facebook is slightly behind but still has a significant share.

# %% [markdown]
# # *BIVARIANT ANALYSIS*

# %% [markdown]
# # ANALYSIS OF ADDICTION LEVEL BY LOCATION

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'Location',y = 'Addiction Level',data = ds_socialtime,palette="mako")
plt.title('Addiction Level by Location')
plt.show()

# %% [markdown]
# *Brazil and Germany show relatively higher addiction levels compared to other countries.
#
# *Asian countries like Pakistan, Vietnam, and Japan tend to have lower addiction levels on average

# %% [markdown]
# # ANALYSING TOTAL NO OF VIDEOS WATCHED BY LOCATION

# %%
location_data=ds_socialtime.groupby("Location")["Number of Videos Watched"].sum().reset_index()
location_data
# Out:
#         Location  Number of Videos Watched
# 0         Barzil                      2129
# 1        Germany                      1441
# 2          India                      5670
# 3      Indonesia                      2147
# 4          Japan                      1987
# 5         Mexico                      1682
# 6       Pakistan                      2009
# 7    Philippines                      1893
# 8  United States                      4554
# 9        Vietnam                      1736

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'Location',y = 'Number of Videos Watched',data =location_data ,palette="mako")
plt.title('TOTAL VIDEOS WATCHED BY LOCATION')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *India has the highest number of videos watched.
#
# *Germany has the lowest number of videos watched.

# %% [markdown]
# # ANALYSIS OF PRODUCTIVITY LOSS BY GENDER WISE

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Gender', y='ProductivityLoss', data=ds_socialtime, estimator=sum,palette="Set1")
plt.title('Total Productivity Loss by Gender')
plt.ylabel('Total Productivity Loss')
plt.xlabel('Gender')
plt.show()

# %% [markdown]
# *Highest Productivity Loss: The ‘Male’ category shows the highest total productivity loss, reaching close to 2500 units.
#
# *Moderate Productivity Loss: The ‘Female’ category has a moderate productivity loss, with the bar indicating a value between 1500 and 2000 units.
#
# *Lowest Productivity Loss: The ‘Other’ category has the lowest productivity loss

# %% [markdown]
# # Relationship between Total Time Spent and Productivity Loss

# %%
plt.figure(figsize=(12,
                    6))
sns.scatterplot(data=ds_socialtime, x='Total Time Spent', y='ProductivityLoss')
plt.title('Total Time Spent vs Productivity Loss')
plt.show()

# %% [markdown]
# # Satisfaction Levels based on Platform

# %%
plt.figure(figsize=(12,
                    6))
sns.boxplot(data=ds_socialtime, x='Platform', y='Satisfaction')
plt.title('Satisfaction Levels by Platform')
plt.show()

# %% [markdown]
# # Finding The Biggest Productivity Loss by Time of The Day

# %%
frequency_productivity_loss = ds_socialtime.groupby('Frequency')['ProductivityLoss'].mean().reset_index()

# Sorting the values to find the biggest productivity loss
frequency_productivity_loss = frequency_productivity_loss.sort_values(by='ProductivityLoss', ascending=False)

# Displaying the results
print(frequency_productivity_loss)

# The results
plt.figure(figsize=(12,
                    6))
plt.bar(frequency_productivity_loss['Frequency'], frequency_productivity_loss['ProductivityLoss'], color=['red', 'orange', 'yellow', 'green'])
plt.xlabel('Frequency')
plt.ylabel('Average Productivity Loss')
plt.title('Average Productivity Loss by Time of Day')
plt.show()
# Out:
#    Frequency  ProductivityLoss
# 2    Morning          7.490566
# 1    Evening          5.890411
# 0  Afternoon          5.345291
# 3      Night          3.267974

# %% [markdown]
# # *MULTI-VARIANT ANALYSIS*

# %% [markdown]
# # ANALYSIS OF FACTORS AFFECTING PRODUCTIVITY LOSS

# %% [markdown]
# *Correlation Matrix: The heatmap reveals the relationships between various features.
#
# *Strong correlations can help identify key factors influencing productivity loss.

# %%
correlation_matrix = ds_socialtime[['ProductivityLoss', 'Addiction Level', 'Engagement', 'Income', 'Self Control','Total Time Spent',
                                    'Video Length','Satisfaction']].corr()
correlation_matrix
# Out:
#                   ProductivityLoss  Addiction Level  Engagement    Income  \
# ProductivityLoss          1.000000        -0.994939   -0.025050  0.040670
# Addiction Level          -0.994939         1.000000    0.027620 -0.039181
# Engagement               -0.025050         0.027620    1.000000 -0.017183
# Income                    0.040670        -0.039181   -0.017183  1.000000
# Self Control              0.994939        -1.000000   -0.027620  0.039181
# Total Time Spent         -0.014210         0.016086   -0.033743  0.013326
# Video Length             -0.004364         0.004914    0.001286  0.017432
# Satisfaction             -1.000000         0.994939    0.025050 -0.040670
#
#                   Self Control  Total Time Spent  Video Length  Satisfaction
# ProductivityLoss      0.994939         -0.014210     -0.004364     -1.000000
# Addiction Level      -1.000000          0.016086      0.004914      0.994939
# Engagement           -0.027620         -0.033743      0.001286      0.025050
# Income                0.039181          0.013326      0.017432     -0.040670
# Self Control          1.000000         -0.016086     -0.004914     -0.994939
# Total Time Spent     -0.016086          1.000000      0.068607      0.014210
# Video Length         -0.004914          0.068607      1.000000      0.004364
# Satisfaction         -0.994939          0.014210      0.004364      1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix,annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Factors Affecting Productivity Loss')
plt.show()

# %% [markdown]
# *Addiction Level: Strongly positively correlated with productivity loss. Higher addiction levels lead to greater productivity loss.
#
# *Income: Weakly positively correlated. Slight increase in productivity loss with higher income.
#
# *Total Time Spent: Moderately positively correlated. More time spent on tasks is linked to higher productivity loss.
#
# *Engagement: Moderately negatively correlated. Higher engagement reduces productivity loss.
#
# *Self-Control: Very strongly negatively correlated. Higher self-control significantly reduces productivity loss.
#
# *Satisfaction: There is a strong negative correlation between satisfaction and productivity loss.
#  This means that higher satisfaction levels are associated with lower productivity loss.

# %% [markdown]
# # SUGGESSIONS TO REDUCE SOCIAL MEDIA'S IMPACT ON PRODUCTIVITY

# %% [markdown]
# *Set Time Limits: Use apps or timers to limit how long you spend on social media.
#
# *Turn Off Notifications: Disable social media alerts to avoid distractions.
#
# *Create Social Media-Free Spaces: Keep social media out of your workspace.
#
# *Use Focus Modes: Activate "Focus Mode" on your phone to block distractions.
#
# *Limit Access: Remove social media apps from your phone or use them only on one device.
#
# *Schedule Breaks: Set specific times to check social media, like during lunch or after work.
#
# *Do Other Activities: Replace scrolling with activities like walking, reading, or hobbies.
#
# *Be Mindful: Think about why you're using social media and track your usage.
#
# *Separate Work and Personal Use: Use social media only for work-related tasks during work hours.
#
# *Take Breaks from Social Media: Try digital detoxes by avoiding social media for certain periods, like weekends.
#
# *These can help you stay focused and productive.

# %%
ds_socialtime["Satisfaction"]
# Out:
# 0      7
# 1      5
# 2      4
# 3      7
# 4      2
#       ..
# 995    1
# 996    2
# 997    1
# 998    7
# 999    4
# Name: Satisfaction, Length: 1000, dtype: int64
